# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('bikes.csv')

# %%
df
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# ...

# %%
df.head(20)
# Out:
#                datetime  season  workingday weather   temp  humidity  \
# 0   2011-01-01 00:00:00  Spring         0.0   Clear   9.84      81.0
# 1   2011-01-01 01:00:00  Spring         0.0     NaN   9.02      80.0
# 2   2011-01-01 02:00:00  Spring         0.0   Clear   9.02       NaN
# 3   2011-01-01 03:00:00  Spring         0.0   Clear   9.84      75.0
# 4   2011-01-01 04:00:00     NaN         0.0   Clear    NaN      75.0
# 5   2011-01-01 05:00:00     NaN         NaN    Mist   9.84       NaN
# 6   2011-01-01 06:00:00  Spring         0.0   Clear    NaN       NaN
# 7   2011-01-01 07:00:00  Spring         0.0   Clear   8.20       NaN
# 8   2011-01-01 08:00:00  Spring         0.0     NaN   9.84       NaN
# 9   2011-01-01 09:00:00  Spring         0.0   Clear    NaN      76.0
# 10  2011-01-01 10:00:00  Spring         0.0   Clear  15.58      76.0
# 11  2011-01-01 11:00:00  Spring         0.0   Clear  14.76      81.0
# 12  2011-01-01 12:00:00  Spring         NaN   Clear    NaN      77.0
# ...

# %%
## Display Rented Bikes Count
df['rented_bikes_count']
# Out:
# 0         16
# 1         40
# 2         32
# 3         13
# 4          1
#         ...
# 10881    336
# 10882    241
# 10883    168
# 10884    129
# 10885     88
# Name: rented_bikes_count, Length: 10886, dtype: int64

# %%
## Display Rented Bikes Count as well as DateTime -> Double Square Bracket
df[['datetime','rented_bikes_count']]
# Out:
#                   datetime  rented_bikes_count
# 0      2011-01-01 00:00:00                  16
# 1      2011-01-01 01:00:00                  40
# 2      2011-01-01 02:00:00                  32
# 3      2011-01-01 03:00:00                  13
# 4      2011-01-01 04:00:00                   1
# ...                    ...                 ...
# 10881  2012-12-19 19:00:00                 336
# 10882  2012-12-19 20:00:00                 241
# 10883  2012-12-19 21:00:00                 168
# 10884  2012-12-19 22:00:00                 129
# 10885  2012-12-19 23:00:00                  88
#
# [10886 rows x 2 columns]

# %%
##Print temperature and rented bikes count if temperature is grater then 15
f= df[df['temp'] > 15]
f[['temp','rented_bikes_count']]
# Out:
#         temp  rented_bikes_count
# 10     15.58                  36
# 13     18.86                  94
# 14     18.86                 106
# 15     18.04                 110
# 16     17.22                  93
# ...      ...                 ...
# 10856  15.58                 525
# 10857  15.58                 353
# 10873  16.40                 200
# 10880  15.58                 569
# 10881  15.58                 336
#
# [5615 rows x 2 columns]

# %%
##Display alternative Rows
df.iloc[:,::2]
# Out:
#                   datetime  holiday weather  humidity  casual  \
# 0      2011-01-01 00:00:00      0.0   Clear      81.0       3
# 1      2011-01-01 01:00:00      0.0     NaN      80.0       8
# 2      2011-01-01 02:00:00      0.0   Clear       NaN       5
# 3      2011-01-01 03:00:00      0.0   Clear      75.0       3
# 4      2011-01-01 04:00:00      0.0   Clear      75.0       0
# ...                    ...      ...     ...       ...     ...
# 10881  2012-12-19 19:00:00      0.0   Clear      50.0       7
# 10882  2012-12-19 20:00:00      0.0     NaN       NaN      10
# 10883  2012-12-19 21:00:00      0.0   Clear      61.0       4
# 10884  2012-12-19 22:00:00      NaN   Clear       NaN      12
# 10885  2012-12-19 23:00:00      0.0   Clear      66.0       4
#
#        rented_bikes_count
# 0                      16
# 1                      40
# 2                      32
# 3                      13
# 4                       1
# ...                   ...
# 10881                 336
# ...

# %%
## Check number of null values present in  registered column
print(df['registered'].isnull().sum())
# Out:
# 0

# %%
## Check number of null values present in  temperature column
print(df['temp'].isnull().sum())
# Out:
# 2782

# %%
print(df['temp'].duplicated().sum())
# Out:
# 10836

# %%
print(df['holiday'].duplicated().sum())
# Out:
# 10883

# %%
del df['holiday']

# %%
df
# Out:
#                   datetime  season  workingday weather   temp  humidity  \
# 0      2011-01-01 00:00:00  Spring         0.0   Clear   9.84      81.0
# 1      2011-01-01 01:00:00  Spring         0.0     NaN   9.02      80.0
# 2      2011-01-01 02:00:00  Spring         0.0   Clear   9.02       NaN
# 3      2011-01-01 03:00:00  Spring         0.0   Clear   9.84      75.0
# 4      2011-01-01 04:00:00     NaN         0.0   Clear    NaN      75.0
# ...                    ...     ...         ...     ...    ...       ...
# 10881  2012-12-19 19:00:00  Winter         1.0   Clear  15.58      50.0
# 10882  2012-12-19 20:00:00  Winter         1.0     NaN  14.76       NaN
# 10883  2012-12-19 21:00:00     NaN         1.0   Clear  13.94      61.0
# 10884  2012-12-19 22:00:00  Winter         1.0   Clear  13.94       NaN
# 10885  2012-12-19 23:00:00  Winter         1.0   Clear  13.12      66.0
#
#        windspeed  casual  registered  rented_bikes_count
# ...

# %%
df.iloc[::1000,::2]
# Out:
#                   datetime  workingday   temp  windspeed  registered
# 0      2011-01-01 00:00:00         0.0   9.84        NaN          13
# 1000   2011-03-06 03:00:00         0.0  17.22        NaN           9
# 2000   2011-05-10 06:00:00         1.0  17.22     8.9981         103
# 3000   2011-07-13 22:00:00         1.0  27.88    12.9980         136
# 4000   2011-09-17 17:00:00         0.0  21.32    15.0013         218
# 5000   2011-12-02 10:00:00         1.0  12.30        NaN          89
# 6000   2012-02-06 06:00:00         1.0   6.56        NaN          72
# 7000   2012-04-10 00:00:00         1.0  18.04        NaN          23
# 8000   2012-06-13 17:00:00         NaN  29.52        NaN         782
# 9000   2012-08-17 09:00:00         1.0  28.70     7.0015         320
# 10000  2012-11-02 01:00:00         1.0  13.12    11.0014          19
